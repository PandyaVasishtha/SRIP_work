# %%
from nltk.translate.bleu_score import sentence_bleu
Queries=[
    "Tell me about Rajasthani Clay Catalytic Converters for Automobiles",
    "Which domain is it related to ?",
    "Is there any patent or work published on it ?",
    "Tell me more about the background of this field",
    "Tell me about catalytic converters"
]
# Standard responses
standard_responses = [
    "Rajasthani Clay Catalytic Converters are a new type of catalytic converter that uses Iron-Nickel-Cobalt nanoparticles embedded in Rajasthani clay. These metal oxides act as oxygen reservoirs, allowing for the complete oxidation of NOx, COx, and hydrocarbons at temperatures below 300°C. This innovative design offers a more cost-effective and sustainable alternative to traditional catalytic converters, which rely on expensive and scarce metals like Cerium and Palladium.",
    "This research falls within the domain of Environmental Science, focusing on reducing automobile emissions.",
    "Yes, there is a patent related to this research. The patent is titled : 'A hydrogen-annealed bimetallic oxide and implementations thereof,' and was filed on August 5, 2019 (Application Number: 201911031662).",
    "The field of catalytic converters is critical for the automotive industry due to increasingly strict emissions regulations aimed at reducing air pollutants such as NOx, COx, and particulate matter. Traditional catalytic converters, known as three-way catalytic converters (TWCs), use rare-earth elements like Cerium and noble metals like Palladium to reduce these emissions. However, these materials are expensive and their supply is limited. Additionally, the performance of these converters deteriorates over time, often before the end of a car's approved life. Research in this area seeks to find cheaper, more sustainable alternatives that can perform effectively at lower temperatures and have a longer lifespan.",
    "Catalytic converters are devices used in automobiles to reduce harmful emissions from the engine. They work by converting toxic gases and pollutants in exhaust gas into less harmful substances. The most common type, the three-way catalytic converter (TWC), reduces nitrogen oxides (NOx) to nitrogen and oxygen, oxidizes carbon monoxide (CO) to carbon dioxide (CO2), and oxidizes unburned hydrocarbons to CO2 and water. Traditional converters use rare-earth metals like Cerium and noble metals like Palladium, which are effective but costly and prone to supply issues.",
]

# Generated responses by llama3
generated_responses = [
    "According to the article written by Rakesh K Sharma, Rajasthani Clay Catalytic Converters for Automobiles is a new non-rare earth, non-noble metal based catalytic convertor that uses Iron-Nickel-Cobalt nanoparticles in Rajasthani Clay. This innovative technology replaces the use of Cerium and Palladium, which are increasing in price and suffering from supply problems. The new converter can completely oxidize NOx, COx, and hydrocarbons at a lower temperature than 300°C. This solution is cheaper and more sustainable than traditional converters that require rare-earth elements and precious metals like Palladium.",
    "According to the text, the technology of Rajasthani Clay Catalytic Converters for Automobiles is related to Environmental Science",
    "According to the text, yes, there is a published patent on the Rajasthani Clay Catalytic Converters for Automobiles. The patent number is A hydrogen-annealed bimetallic oxide and implementations thereof (201911031662), with an application date of August 5, 2019.",
    "Based on the provided context, here's what I can tell you about the background of this field: The automotive industry is facing stricter emissions regulations to reduce the amount of harmful air pollutants released into the environment. These pollutants include NOx (nitrogen oxides), COx (carbon monoxide), and particulate matter (soot). The current method for reducing these emissions involves three-way catalytic converters, which use rare-earth elements like Cerium (Ce) and Palladium to convert harmful gases into harmless ones. However, this technology has some limitations. One major issue is the high cost of these rare-earth elements, particularly Palladium, which makes up a significant portion of the converter's cost. A single catalytic converter can contain around 5-7 grams of pure Palladium, valued at around $60 per gram (more expensive than gold!). Additionally, the performance of these converters degrades over time, requiring replacement after about 8-10 years. This has led researchers to explore alternative solutions to reduce emissions and develop more cost-effective catalytic converters. The study you're referring to aims to address these challenges by using non-noble metals and exploring novel catalyst designs.",
    "According to the text, the limitations of traditional catalytic converters include: Deactivation over time: The performance of the converter decreases with time, typically after 8-10 years. High cost: Each catalytic converter contains about 5-7 grams of pure palladium, which costs around 60 per gram, making it one of the most expensive parts of acar(pricerange : $1000-$1500).Dependence on rare-earth elements: Traditional converters require the use of rare-earth elements like Cerium and Palladium, which are increasing in price and suffering from supply problems.These limitations motivated Prof. Sharma's research team to seek an alternative solution by understanding catalytic converter deactivation and finding a cheaper solution.",
]
i=0
# Calculate BLEU score for each response pair
bleu_scores = []
for ref, hyp in zip(standard_responses, generated_responses):
    i=i+1
    ref_tokens = ref.split()
    hyp_tokens = hyp.split()
    bleu_score = sentence_bleu(
        [ref_tokens], hyp_tokens, weights=(1,0,0,0)
    )
    bleu_scores.append(bleu_score)
    print(
        f"BLEU Score for Qeury-{i}: {bleu_score:.4f} "
    )

# Calculate average BLEU score
average_bleu_score = sum(bleu_scores) / len(bleu_scores)
print(f"Average BLEU Score for 'Llama-3' : {average_bleu_score:.4f}")
# Out:
# BLEU Score for Qeury-1: 0.4598
# BLEU Score for Qeury-2: 0.1667
# BLEU Score for Qeury-3: 0.4211
# BLEU Score for Qeury-4: 0.2961
# BLEU Score for Qeury-5: 0.2451
# Average BLEU Score for 'Llama-3' : 0.3177

# %%
from nltk.translate.bleu_score import sentence_bleu

# Standard responses
standard_responses = {
    'q1': "Rajasthani Clay Catalytic Converters are a new type of catalytic converter that uses Iron-Nickel-Cobalt nanoparticles embedded in Rajasthani clay. These metal oxides act as oxygen reservoirs, allowing for the complete oxidation of NOx, COx, and hydrocarbons at temperatures below 300°C. This innovative design offers a more cost-effective and sustainable alternative to traditional catalytic converters, which rely on expensive and scarce metals like Cerium and Palladium.",
    'q2': "This research falls within the domain of Environmental Science, focusing on reducing automobile emissions.",
    'q3': "Yes, there is a patent related to this research. The patent is titled : 'A hydrogen-annealed bimetallic oxide and implementations thereof,' and was filed on August 5, 2019 (Application Number: 201911031662).",
    'q4': "The field of catalytic converters is critical for the automotive industry due to increasingly strict emissions regulations aimed at reducing air pollutants such as NOx, COx, and particulate matter. Traditional catalytic converters, known as three-way catalytic converters (TWCs), use rare-earth elements like Cerium and noble metals like Palladium to reduce these emissions. However, these materials are expensive and their supply is limited. Additionally, the performance of these converters deteriorates over time, often before the end of a car's approved life. Research in this area seeks to find cheaper, more sustainable alternatives that can perform effectively at lower temperatures and have a longer lifespan.",
    'q5': "Catalytic converters are devices used in automobiles to reduce harmful emissions from the engine. They work by converting toxic gases and pollutants in exhaust gas into less harmful substances. The most common type, the three-way catalytic converter (TWC), reduces nitrogen oxides (NOx) to nitrogen and oxygen, oxidizes carbon monoxide (CO) to carbon dioxide (CO2), and oxidizes unburned hydrocarbons to CO2 and water. Traditional converters use rare-earth metals like Cerium and noble metals like Palladium, which are effective but costly and prone to supply issues."
}

# Generated responses by gpt2
generated_responses = {
    'q1': "I have been working on this project for some time now, and it has been a long time since I had a chance to work on it. I am very happy with the results of my work, but I have a lot of questions about it, so I will try my best to answer them as soon as possible. First of all, I would like to say thank you to all the people who have helped me out in the past few years. You have made a huge difference in my life and I hope that you will continue to support me in this endeavor. Thank you very much for your support and support of the project.",
    'q2': "It is important to note that this is not a scientific question.  It is just a question of finding a better solution to the problem. Source: http://www.ncbi.nlm.nih.gov/pmc/articles/PMC170189/ http://en.wikipedia.org/wiki/Research_Domain_of_NOx_COX_and_soot",
    'q3': "No, there is no patent on this metal oxide. However, it is possible to use it as an oxidizer. Source: http://www.sciencedirect.com/science/article/pii/S0114102901010009/full/abstract",
    'q4': "I am a PhD student in the Department of Atmospheric Sciences at the University of Delhi. I have been studying the effects of climate change on the Earth's climate system for over 20 years. In this article, I want to share with you some of the results of my research. I have studied the effect of global warming on atmospheric carbon dioxide (CO2) levels in a variety of ways. The most important of which is that CO2 is a greenhouse gas, which means that it is released into the atmosphere by the burning of fossil fuels. As a result, it has a negative impact on human health and well-being. However, this is not the only reason for this negative effect. There are also other factors that contribute to the negative effects. For example, the amount of CO 2 released by human activities is very low. Therefore, there is no reason to believe that human activity is responsible for the increase in atmospheric CO two-thirds to one-third of a degree above pre-industrial levels. It is also important to note that there are many different types of greenhouse gases, such as methane, nitrous oxide, carbon monoxide, nitrogen oxides, and so on. All of these gases are produced by burning fossil fuel. This is because they are the main source of energy for plants and animals. These gases also have a positive effect on water quality, as well as on air quality. So, we need to understand how these different gases interact with each other and how they affect the climate.",
    'q5': "They are the most expensive part in the car. They cost a lot of money to produce, but they are also the cheapest to use. In fact, they cost more than any other part on the market. It is not that expensive, it is just that they do not work as well as other catalysts. So, if you want to make a car that is more efficient, you have to buy more expensive parts. If you don't, then you will not be able to get the best performance out of them. So, what is the difference between a catalyst and a converter? A catalyst is a type of catalyst that can be used to convert metal into electricity. A converter is another type that converts metal to electrical energy. There are many different types of converter, and they all have their advantages and disadvantages. For example, there are some that are more cost effective than others, while others are less efficient. Some of these are: 1. Copper 2. Iron 3. Aluminum 4. Stainless Steel 5. Nickel 6. Manganese 7. Titanium 8. Lead 9. Tin 10. Gold 11. Silver 12. Platinum 13. Zinc 14. Chromium 15. Magnesium 16. Potassium 17. Selenium "
}

# Calculate BLEU score for each response pair and average
bleu_scores = []
for key in standard_responses.keys():
    ref = standard_responses[key]
    hyp = generated_responses[key]

    ref_tokens = ref.split()
    hyp_tokens = hyp.split()

    bleu_score = sentence_bleu([ref_tokens], hyp_tokens, weights=(1, 0, 0, 0))
    bleu_scores.append(bleu_score)

    print(f"BLEU Score ({key}): {bleu_score:.4f}")

# Calculate average BLEU score
average_bleu_score = sum(bleu_scores) / len(bleu_scores)
print(f"Average BLEU Score for 'GPT-2' : {average_bleu_score:.4f}")
# Out:
# BLEU Score (q1): 0.1282
# BLEU Score (q2): 0.0714
# BLEU Score (q3): 0.2070
# BLEU Score (q4): 0.1279
# BLEU Score (q5): 0.1100
# Average BLEU Score for 'GPT-2' : 0.1289

# %%
import matplotlib.pyplot as plt

# BLEU scores for llama3 and gpt-2
models = ['llama3', 'gpt-2']
average_bleu_scores = [0.3177, 0.1289]

# Plot BLEU scores
plt.figure(figsize=(8, 6))
plt.bar(models, average_bleu_scores, color=['blue', 'green'])
plt.xlabel('Models')
plt.ylabel('Average BLEU Score')
plt.title('Average BLEU Score Comparison between llama3 and gpt-2')
plt.ylim(0, 1)  # Setting the limit from 0 to 1 for better visualization of scores

# Annotate the bars with the score values
for i, score in enumerate(average_bleu_scores):
    plt.text(i, score + 0.02, f'{score:.4f}', ha='center', fontsize=12)

plt.show()
